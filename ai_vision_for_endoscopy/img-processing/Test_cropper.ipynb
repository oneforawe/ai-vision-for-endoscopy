# %%
import PIL
from PIL import Image, crop
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-14-e71072b07274> in <module>
#       1 import PIL
# ----> 2 from PIL import Image, crop
#
# ImportError: cannot import name 'crop'

# %%
# box = (X_offset, Y_offset, width, height)
# crop = image.crop(box)
# return crop.save(image_path, format)

filenames = ['1376916 20 Dec 18_1 140.jpg',
             '2488865 12 Dec 18_1 0207.jpg',
             '2488865 12 Dec 18_1 1591.jpg',
             '2805206 01 Dec 18_1 08.jpg',
             '11043364 28 Nov 18_1 0001.jpg',
             '11043364 28 Nov 18_1 1606.jpg']

img = Image.open(filenames[0])
#img.rotate(45).show()

box = (25, 25, 50, 50)
crop_img = img.crop(box)
crop_img.save('01', jpg)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-a12a893198fb> in <module>
#      10              '11043364 28 Nov 18_1 1606.jpg']
#      11
# ---> 12 img = Image.open(filenames[0])
#      13 #img.rotate(45).show()
#      14
#
# ~/Tools/anaconda3/lib/python3.6/site-packages/PIL/Image.py in open(fp, mode)
#    2607
#    2608     if filename:
# -> 2609         fp = builtins.open(filename, "rb")
#    2610         exclusive_fp = True
#    2611
#
# FileNotFoundError: [Errno 2] No such file or directory: '1376916 20 Dec 18_1 140.jpg'

# %%
from PIL import ImageOps
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image

# %matplotlib inline
pil_img = Image.open(filenames[0], 'r')
#imshow(np.asarray(pil_img))

border = (32, 32, 32, 32) # left, top, right, bottom
#cropped_img = ImageOps.crop(img, border)
#cropped_img.save('01.jpg')
ImageOps.crop(img, border)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x121BED208>

# %%
filenames = ['1376916 20 Dec 18_1 0088.jpg']

img = Image.open(filenames[0])
#img.rotate(45).show()

box = (25, 25, 50, 50)
crop_img = img.crop(box)
crop_img.save('01.jpg', 'JPEG')

# %%
from PIL import ImageOps
from PIL import Image
#from ImageDraw import polygon
#from PIL import ImageDraw.Draw.polygon
#from PIL.ImageDraw.Draw import polygon
from matplotlib.pyplot import imshow
import numpy as np

# %matplotlib inline

pil_img = Image.open(filenames[0], 'r')
#imshow(np.asarray(pil_img))

border = (32, 32, 32, 32) # left, top, right, bottom
#cropped_img = ImageOps.crop(img, border)
#cropped_img.save('01.jpg')
cropped = ImageOps.crop(img, border)

#final = cropped.polygon([(0,0),(100,0),(0,100)], fill=black, outline=red)

print(cropped)
print(np.asarray(cropped).shape)

#black_covering = Image.new('RGB', (512,512), (255,0,0,0))

poly = Image.new('RGBA', (512,512), (0,255,0,255))
pdraw = ImageDraw.Draw(poly)
pdraw.polygon([(0,125),(50,50),(125,0),(512-125,0),(512-50,50),(512,125),
               (512,512-125),(512-50,512-50),(512-125,512),(125,512),(50,512-50),(0,512-125)],
              fill=(0,0,0,0))
masked = cropped.paste(poly,mask=poly)
print(type(cropped))
print(type(masked))
cropped
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x11361EB70>
# (512, 512, 3)
# <class 'PIL.Image.Image'>
# <class 'NoneType'>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x11361EB70>

# %%
import PIL.ImageOps
#img = Image.open("")
back = Image.new('RGBA', (512,512))
back.paste(cropped)
poly = Image.new('RGBA', (512,512))
pdraw = ImageDraw.Draw(poly)
pdraw.rectangle([(10,10),(100,100)],
          fill=(255,255,255,200))
inverted_poly = ImageOps.invert(poly)
back.paste(poly, (0,0), mask=inverted_poly)
back.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-53-15b4918ff8a3> in <module>
#       7 pdraw.rectangle([(10,10),(100,100)],
#       8           fill=(255,255,255,200))
# ----> 9 inverted_poly = ImageOps.invert(poly)
#      10 back.paste(poly, (0,0), mask=inverted_poly)
#      11 back.show()
#
# ~/Tools/anaconda3/lib/python3.6/site-packages/PIL/ImageOps.py in invert(image)
#     493     for i in range(256):
#     494         lut.append(255-i)
# --> 495     return _lut(image, lut)
#     496
#     497
#
# ~/Tools/anaconda3/lib/python3.6/site-packages/PIL/ImageOps.py in _lut(image, lut)
#      55         return image.point(lut)
#      56     else:
# ---> 57         raise IOError("not supported for this image mode")
#      58
#      59 #
#
# OSError: not supported for this image mode
